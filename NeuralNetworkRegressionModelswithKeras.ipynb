# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeeTeeee/ibm.ai_Engineering_Professional_Cert/blob/main/NeuralNetworkRegressionModelswithKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:
#
# 1. Cement
#
# 2. Blast Furnace Slag
#
# 3. Fly Ash
#
# 4. Water
#
# 5. Superplasticizer
#
# 6. Coarse Aggregate
#
# 7. Fine Aggregate

# %%
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
#read in the dataset:
concrete = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Let us check to understand our data first

# %%
concrete.shape
# Out:
# (1030, 9)

# %% [markdown]
# we can see our dataset has 1030 rowws and 9 columns, we will now use the describe() funcion to know the statistics of our data

# %%
concrete.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# the `Strength` column been the target, we can see that the min is 2 and the max is 87.
#
# Lets go on by checking if there are any null or missing values in our dataset:

# %%
concrete.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# its clean and no `null` value.
# Let us split the dataset into predictors and target

# %%
#split data:
# concrete_cols = concrete.columns
# predictors = concrete[concrete_cols[concrete_cols !='Strength']]
# target = concrete['Strength']
# Split data into predictors and target
concrete_cols = concrete.columns
predictors = concrete.loc[:, concrete_cols != 'Strength']
target = concrete['Strength']

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# We can try to normalize our data now:

# %%
predictors_normal = (predictors - predictors.mean()) / predictors.std()
predictors_normal
# Out:
#         Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4    -0.790075            0.678079 -0.846733  0.488555         -1.038638
# ...        ...                 ...       ...       ...               ...
# 1025 -0.045623            0.487998  0.564271 -0.092126          0.451190
# 1026  0.392628           -0.856472  0.959602  0.675872          0.702285
# 1027 -1.269472            0.759210  0.850222  0.521336         -0.017520
# 1028 -1.168042            1.307430 -0.846733 -0.279443          0.852942
# 1029 -0.193939            0.308349  0.376762  0.891286          0.400971
#
#       Coarse Aggregate  Fine Aggregate       Age
# 0             0.862735       -1.217079 -0.279597
# 1             1.055651       -1.217079 -0.279597
# 2            -0.526262       -2.239829  3.551340
# 3            -0.526262       -2.239829  5.055221
# 4             0.070492        0.647569  4.976069
# ...                ...             ...       ...
# 1025         -1.322363       -0.065861 -0.279597
# 1026         -1.993711        0.496651 -0.279597
# 1027         -1.035561        0.080068 -0.279597
# 1028          0.214537        0.191074 -0.279597
# 1029         -1.394385       -0.150675 -0.279597
#
# [1030 rows x 8 columns]

# %% [markdown]
# Lets save the column number

# %%
n_cols = predictors.shape[1]
n_cols
# Out:
# 8

# %% [markdown]
# ## Build the Neural Network

# %%
#from keras.src.engine.training import optimizer
#define regression model we will use:
def regression_model(n_cols):
  model = Sequential()
  model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
  model.add(Dense(50, activation='relu'))
  model.add(Dense(1))

  #compile the model:
  model.compile(optimizer='adam', loss='mean_squared_error')
  return model

# %%
regression_model
# Out:
# <function __main__.regression_model(n_cols)>

# %% [markdown]
# ## Lets Train and Test the Network

# %%
model = regression_model(n_cols)

# %%
#fit the model:
model.fit(predictors_normal, target, validation_split = 0.3, epochs= 100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - loss: 1683.7950 - val_loss: 1176.8256 - 1s/epoch - 44ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1585.5414 - val_loss: 1091.0361 - 87ms/epoch - 4ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1449.5839 - val_loss: 967.0419 - 127ms/epoch - 6ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 1244.4423 - val_loss: 791.4470 - 97ms/epoch - 4ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 961.4830 - val_loss: 580.9697 - 92ms/epoch - 4ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 652.5408 - val_loss: 381.7388 - 87ms/epoch - 4ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 395.5760 - val_loss: 249.9617 - 94ms/epoch - 4ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 275.4817 - val_loss: 191.0972 - 99ms/epoch - 4ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 237.1956 - val_loss: 177.9617 - 92ms/epoch - 4ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 221.6407 - val_loss: 171.2812 - 87ms/epoch - 4ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 209.2512 - val_loss: 166.7726 - 87ms/epoch - 4ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 200.6471 - val_loss: 164.5571 - 85ms/epoch - 4ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 193.5611 - val_loss: 161.5716 - 90ms/epoch - 4ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 187.1543 - val_loss: 161.4991 - 87ms/epoch - 4ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 182.5868 - val_loss: 158.9970 - 86ms/epoch - 4ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 178.0680 - val_loss: 158.2395 - 91ms/epoch - 4ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 174.9526 - val_loss: 158.9119 - 99ms/epoch - 4ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 170.7706 - val_loss: 159.5549 - 89ms/epoch - 4ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 167.4074 - val_loss: 157.4590 - 102ms/epoch - 4ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 164.1232 - val_loss: 156.5648 - 173ms/epoch - 8ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 161.2345 - val_loss: 157.1944 - 167ms/epoch - 7ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 158.4709 - val_loss: 156.5458 - 136ms/epoch - 6ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 155.8549 - val_loss: 156.3877 - 165ms/epoch - 7ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 153.3389 - val_loss: 155.4249 - 116ms/epoch - 5ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 151.3439 - val_loss: 155.4339 - 110ms/epoch - 5ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 149.9292 - val_loss: 156.6622 - 131ms/epoch - 6ms/step
# Epoch 27/100
# 23/23 - 0s - loss: 147.3983 - val_loss: 159.5375 - 113ms/epoch - 5ms/step
# Epoch 28/100
# 23/23 - 0s - loss: 146.2705 - val_loss: 158.8672 - 116ms/epoch - 5ms/step
# Epoch 29/100
# 23/23 - 0s - loss: 143.9346 - val_loss: 158.0410 - 111ms/epoch - 5ms/step
# Epoch 30/100
# 23/23 - 0s - loss: 142.5502 - val_loss: 158.6695 - 116ms/epoch - 5ms/step
# Epoch 31/100
# 23/23 - 0s - loss: 141.3194 - val_loss: 160.6716 - 120ms/epoch - 5ms/step
# Epoch 32/100
# 23/23 - 0s - loss: 139.0167 - val_loss: 159.5654 - 111ms/epoch - 5ms/step
# Epoch 33/100
# 23/23 - 0s - loss: 137.7819 - val_loss: 161.8456 - 105ms/epoch - 5ms/step
# Epoch 34/100
# 23/23 - 0s - loss: 136.2749 - val_loss: 161.8202 - 123ms/epoch - 5ms/step
# Epoch 35/100
# 23/23 - 0s - loss: 134.0048 - val_loss: 160.3719 - 182ms/epoch - 8ms/step
# Epoch 36/100
# 23/23 - 0s - loss: 132.9885 - val_loss: 162.1854 - 116ms/epoch - 5ms/step
# Epoch 37/100
# 23/23 - 0s - loss: 131.6183 - val_loss: 160.2616 - 175ms/epoch - 8ms/step
# Epoch 38/100
# 23/23 - 0s - loss: 129.5373 - val_loss: 163.8494 - 166ms/epoch - 7ms/step
# Epoch 39/100
# 23/23 - 0s - loss: 128.1588 - val_loss: 162.1746 - 96ms/epoch - 4ms/step
# Epoch 40/100
# 23/23 - 0s - loss: 127.0457 - val_loss: 161.6180 - 87ms/epoch - 4ms/step
# Epoch 41/100
# 23/23 - 0s - loss: 125.2542 - val_loss: 162.5561 - 82ms/epoch - 4ms/step
# Epoch 42/100
# 23/23 - 0s - loss: 124.2628 - val_loss: 158.5260 - 86ms/epoch - 4ms/step
# Epoch 43/100
# 23/23 - 0s - loss: 122.4804 - val_loss: 162.2433 - 93ms/epoch - 4ms/step
# Epoch 44/100
# 23/23 - 0s - loss: 121.4069 - val_loss: 159.7037 - 99ms/epoch - 4ms/step
# Epoch 45/100
# 23/23 - 0s - loss: 119.4111 - val_loss: 160.0757 - 82ms/epoch - 4ms/step
# Epoch 46/100
# 23/23 - 0s - loss: 118.4931 - val_loss: 158.0377 - 84ms/epoch - 4ms/step
# Epoch 47/100
# 23/23 - 0s - loss: 117.0603 - val_loss: 157.4463 - 100ms/epoch - 4ms/step
# Epoch 48/100
# 23/23 - 0s - loss: 115.2066 - val_loss: 156.3405 - 90ms/epoch - 4ms/step
# Epoch 49/100
# 23/23 - 0s - loss: 113.7998 - val_loss: 156.0119 - 76ms/epoch - 3ms/step
# Epoch 50/100
# 23/23 - 0s - loss: 113.6598 - val_loss: 156.1255 - 87ms/epoch - 4ms/step
# Epoch 51/100
# 23/23 - 0s - loss: 110.1995 - val_loss: 152.5909 - 89ms/epoch - 4ms/step
# Epoch 52/100
# 23/23 - 0s - loss: 109.3497 - val_loss: 154.6329 - 93ms/epoch - 4ms/step
# Epoch 53/100
# 23/23 - 0s - loss: 106.5910 - val_loss: 148.5487 - 86ms/epoch - 4ms/step
# Epoch 54/100
# 23/23 - 0s - loss: 105.0330 - val_loss: 149.9072 - 78ms/epoch - 3ms/step
# Epoch 55/100
# 23/23 - 0s - loss: 103.3763 - val_loss: 146.2641 - 100ms/epoch - 4ms/step
# Epoch 56/100
# 23/23 - 0s - loss: 101.0534 - val_loss: 144.4186 - 77ms/epoch - 3ms/step
# Epoch 57/100
# 23/23 - 0s - loss: 99.6963 - val_loss: 143.4348 - 87ms/epoch - 4ms/step
# Epoch 58/100
# 23/23 - 0s - loss: 96.5020 - val_loss: 140.3983 - 92ms/epoch - 4ms/step
# Epoch 59/100
# 23/23 - 0s - loss: 94.3761 - val_loss: 138.7442 - 89ms/epoch - 4ms/step
# Epoch 60/100
# 23/23 - 0s - loss: 91.6490 - val_loss: 134.0701 - 93ms/epoch - 4ms/step
# Epoch 61/100
# 23/23 - 0s - loss: 89.5213 - val_loss: 134.8216 - 91ms/epoch - 4ms/step
# Epoch 62/100
# 23/23 - 0s - loss: 85.7940 - val_loss: 125.9285 - 82ms/epoch - 4ms/step
# Epoch 63/100
# 23/23 - 0s - loss: 83.5430 - val_loss: 126.3721 - 95ms/epoch - 4ms/step
# Epoch 64/100
# 23/23 - 0s - loss: 79.9793 - val_loss: 119.8835 - 89ms/epoch - 4ms/step
# Epoch 65/100
# 23/23 - 0s - loss: 77.2586 - val_loss: 124.8107 - 81ms/epoch - 4ms/step
# Epoch 66/100
# 23/23 - 0s - loss: 73.6112 - val_loss: 113.5934 - 103ms/epoch - 4ms/step
# Epoch 67/100
# 23/23 - 0s - loss: 70.4619 - val_loss: 113.1705 - 84ms/epoch - 4ms/step
# Epoch 68/100
# 23/23 - 0s - loss: 66.6203 - val_loss: 112.6291 - 92ms/epoch - 4ms/step
# Epoch 69/100
# 23/23 - 0s - loss: 63.3670 - val_loss: 101.4556 - 90ms/epoch - 4ms/step
# Epoch 70/100
# 23/23 - 0s - loss: 60.6338 - val_loss: 107.5068 - 87ms/epoch - 4ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 57.8620 - val_loss: 105.9059 - 86ms/epoch - 4ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 54.9228 - val_loss: 102.1656 - 92ms/epoch - 4ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 53.2673 - val_loss: 105.0724 - 79ms/epoch - 3ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 51.4546 - val_loss: 111.6611 - 91ms/epoch - 4ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 49.3366 - val_loss: 98.4370 - 96ms/epoch - 4ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 47.4667 - val_loss: 99.9025 - 83ms/epoch - 4ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 45.6858 - val_loss: 100.8570 - 89ms/epoch - 4ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 44.6189 - val_loss: 94.8120 - 78ms/epoch - 3ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 44.2326 - val_loss: 96.2339 - 106ms/epoch - 5ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 41.6658 - val_loss: 105.6311 - 82ms/epoch - 4ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 40.6276 - val_loss: 111.6955 - 91ms/epoch - 4ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 39.6874 - val_loss: 102.2501 - 84ms/epoch - 4ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 38.4177 - val_loss: 110.6551 - 95ms/epoch - 4ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 37.4132 - val_loss: 97.8310 - 87ms/epoch - 4ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 37.1727 - val_loss: 122.4467 - 91ms/epoch - 4ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 36.6359 - val_loss: 101.2587 - 95ms/epoch - 4ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 36.0798 - val_loss: 102.6199 - 87ms/epoch - 4ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 35.5608 - val_loss: 111.5932 - 97ms/epoch - 4ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 34.5486 - val_loss: 109.7236 - 81ms/epoch - 4ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 33.9166 - val_loss: 108.5880 - 86ms/epoch - 4ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 33.5004 - val_loss: 109.2537 - 84ms/epoch - 4ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 32.8472 - val_loss: 115.5195 - 97ms/epoch - 4ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 32.4892 - val_loss: 114.2476 - 89ms/epoch - 4ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 32.1553 - val_loss: 120.1596 - 89ms/epoch - 4ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 32.5150 - val_loss: 105.2586 - 78ms/epoch - 3ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 31.3673 - val_loss: 109.3778 - 88ms/epoch - 4ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 31.1309 - val_loss: 117.1208 - 90ms/epoch - 4ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 30.8912 - val_loss: 112.4633 - 94ms/epoch - 4ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 30.2562 - val_loss: 119.8375 - 107ms/epoch - 5ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 30.0716 - val_loss: 119.3208 - 85ms/epoch - 4ms/step
